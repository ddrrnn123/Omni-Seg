# %% [markdown]
# *   The purpose of this script is to test pretrained model of Omni-Seg on Colab.
#
# *   Current working directory of this script is "/content/drive/My Drive/Omni-Seg". GPU runtime is selected
#
# *   Please download the whole folder from github and upload it on your own google drive to run the test. Changing directory to the folder Omni-Seg if needed.
#
# *   Pretrained model should be put into "snapshots_2D" folder which already contains 2 pretrained models in it.
#
# *   Testing set is in the folder "KI_data_testingset_demo", where "data_list.csv" contains image-paths, label-paths and names. Please use "MOTDataset_2D_Patch_normal_save_csv.py" to generate csv file for the new testing set.
#
# *   Testing file is "Testing_2D_patch_OmniSeg.py". To test a certain model, please pass in the path for argument "--reload_path".
#
#   *   Ex: !python Testing_2D_patch_OmniSeg.py --reload_path 'snapshots_2D/fold1_with_white_Omni-Seg_normalwhole_1201/MOTS_DynConv_fold1_with_white_UNet2D_ns_normalwhole_1106_e89.pth'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !sudo ln -sf /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0.14.0 /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0

# %%
cd /content/drive/My Drive/Omni-Seg
# Out:
# /content/drive/My Drive/Omni-Seg

# %%
# !git clone https://github.com/NVIDIA/apex
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 9171, done.
# remote: Counting objects: 100% (242/242), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 9171 (delta 129), reused 177 (delta 90), pack-reused 8929
# Receiving objects: 100% (9171/9171), 14.63 MiB | 7.85 MiB/s, done.
# Resolving deltas: 100% (6242/6242), done.
# Checking out files: 100% (422/422), done.

# %%
# %cd apex
# !python3 setup.py install
# %cd ..
# Out:
# /content/drive/MyDrive/Omni-Seg/apex
#
#
# torch.__version__  = 1.10.0+cu111
#
#
# setup.py:109: UserWarning: Option --pyprof not specified. Not installing PyProf dependencies!
#   warnings.warn("Option --pyprof not specified. Not installing PyProf dependencies!")
# running install
# running bdist_egg
# running egg_info
# creating apex.egg-info
# writing apex.egg-info/PKG-INFO
# writing dependency_links to apex.egg-info/dependency_links.txt
# writing top-level names to apex.egg-info/top_level.txt
# writing manifest file 'apex.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'apex.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/apex
# copying apex/__init__.py -> build/lib/apex
# copying apex/_autocast_utils.py -> build/lib/apex
# creating build/lib/apex/RNN
# copying apex/RNN/RNNBackend.py -> build/lib/apex/RNN
# ...

# %%
# !pip install tensorboardX
# !pip install SimpleITK
# Out:
# ...
#      |████████████████████████████████| 125 kB 4.4 MB/s
# ...
#      |████████████████████████████████| 48.4 MB 2.1 MB/s
# ...

# %%
# !wget https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# !apt-key add /var/cuda-repo-9-0-local/7fa2af80.pub
# !apt-get update
# !apt-get install cuda=9.0.176-1
# Out:
# --2022-03-23 18:54:41--  https://developer.nvidia.com/compute/cuda/9.0/Prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 152.199.39.144
# Connecting to developer.nvidia.com (developer.nvidia.com)|152.199.39.144|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://developer.nvidia.com/compute/cuda/9.0/prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb [following]
# --2022-03-23 18:54:43--  https://developer.nvidia.com/compute/cuda/9.0/prod/local_installers/cuda-repo-ubuntu1604-9-0-local_9.0.176-1_amd64-deb
# Reusing existing connection to developer.nvidia.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !python Testing_2D_patch_OmniSeg.py --reload_path 'snapshots_2D/fold1_with_white_Omni-Seg_normalwhole_1201/MOTS_DynConv_fold1_with_white_UNet2D_ns_normalwhole_1106_e89.pth'
# Out:
# ArgumentParser(prog='Testing_2D_patch_OmniSeg.py', usage=None, description='DeepLabV3', formatter_class=<class 'argparse.HelpFormatter'>, conflict_handler='error', add_help=True)
# 23 18:59:38 PyTorch Version 1.10.0+cu111
# Using DynConv 8,8,2
# total params: 	6033238
# loading from checkpoint: snapshots_2D/fold1_with_white_Omni-Seg_normalwhole_1201/MOTS_DynConv_fold1_with_white_UNet2D_ns_normalwhole_1106_e89.pth
# 110 images are loaded!
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Validate
#  0dt_f1=0.8512 0dt_dsc=0.8512 0dt_hd=58.81 0dt_msd=9.688
# ...
